# %%
# %cd YoloV3
from models.yolo.yolo_decoder import YoloDecoder

model = YoloDecoder("cfg/yolov3-custom.cfg").to("cuda")

# !pip install torchsummary
from torchsummary import summary

summary(model, input_size=(3, 384, 384))
# Out:
# [WinError 2] The system cannot find the file specified: 'YoloV3'
# c:\Users\naman\Desktop\UnnamedBigProjectName
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# ...
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 32, 384, 384]             864
#        BatchNorm2d-2         [-1, 32, 384, 384]              64
#          LeakyReLU-3         [-1, 32, 384, 384]               0
#             Conv2d-4         [-1, 64, 192, 192]          18,432
#        BatchNorm2d-5         [-1, 64, 192, 192]             128
#          LeakyReLU-6         [-1, 64, 192, 192]               0
#             Conv2d-7         [-1, 32, 192, 192]           2,048
#        BatchNorm2d-8         [-1, 32, 192, 192]              64
#          LeakyReLU-9         [-1, 32, 192, 192]               0
#            Conv2d-10         [-1, 64, 192, 192]          18,432
# ...
