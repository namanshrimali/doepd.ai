# %%
# !git clone https://github.com/namanshrimali/doepd.ai.git
# Out:
# Cloning into 'doepd.ai'...
# remote: Enumerating objects: 764, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 764 (delta 40), reused 56 (delta 22), pack-reused 685
# Receiving objects: 100% (764/764), 11.07 MiB | 12.45 MiB/s, done.
# Resolving deltas: 100% (427/427), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r "/content/drive/MyDrive/doepd/weights/" "/content/doepd.ai/" -v
# Out:
# '/content/drive/MyDrive/doepd/weights/' -> '/content/doepd.ai/weights'
# '/content/drive/MyDrive/doepd/weights/model-f6b98070.pt' -> '/content/doepd.ai/weights/model-f6b98070.pt'
# '/content/drive/MyDrive/doepd/weights/doepd_yolo_best.pt' -> '/content/doepd.ai/weights/doepd_yolo_best.pt'
# '/content/drive/MyDrive/doepd/weights/doepd_yolo_last.pt' -> '/content/doepd.ai/weights/doepd_yolo_last.pt'

# %%
# %cd doepd.ai
# !python inference.py --source "/content/doepd.ai/input/" --output "/content/doepd.ai/output" --run-mode "all"
# Out:
# /content/doepd.ai
# Namespace(conf_thres=0.3, device='', fourcc='mp4v', img_size=512, iou_thres=0.6, names='data/custom.names', output='/content/doepd.ai/output', run_mode='all', source='/content/doepd.ai/input/')
# Using CPU
#
# Loading weights:  weights/model-f6b98070.pt
# Downloading: "https://github.com/facebookresearch/WSL-Images/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://download.pytorch.org/models/ig_resnext101_32x8-c38310e5.pth" to /root/.cache/torch/hub/checkpoints/ig_resnext101_32x8-c38310e5.pth
# 100% 340M/340M [00:03<00:00, 89.9MB/s]
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 48 layers, 5.21710e+06 parameters, 5.21710e+06 gradients
#   processing image /content/doepd.ai/input/example_image.jpg (1/2)
# 320x512 3 hardhats, Done.
# 480x852 Depth Done
# Inferencing completed in 6.419s
# Results saved to /content/doepd.ai/output
# ...

# %%
from IPython.display import Image

# %%
Image(filename='output/example_image_depth.png')

# %%
Image(filename='output/example_image_yolo.png')

# %%
Image(filename='output/example_image2_depth.png')

# %%
Image(filename='output/example_image2_yolo.png')
